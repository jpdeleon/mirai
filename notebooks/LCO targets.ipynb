# %% [markdown]
# # NRES @ Chile, Texas, Israel, and South Africa

# %%
from pathlib import Path
import pandas as pd
import chronos as cr
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %% [markdown]
# ## RV
# * Tmag
# * Rp
# * Porb
# * assume mass and compute semi-amplitude, K
# * SNR -> exposure time * nspectra + overheads

# %%
fp = Path(cr.DATA_PATH, "TOIs2.csv")
df = pd.read_csv(fp)
df.head()
# Out:
#       TIC ID     TOI Previous CTOI  Master  SG1A  SG1B  SG2  SG3  SG4  SG5  \
# 0  231663901  101.01           NaN       5     5     5    5    5    5    5
# 1  149603524  102.01           NaN       5     5     5    5    5    5    5
# 2  336732616  103.01           NaN       5     5     5    5    5    5    5
# 3  231670397  104.01           NaN       5     5     5    5    5    5    5
# 4  144065872  105.01           NaN       5     5     5    5    5    5    5
#
#    ...  Date TOI Alerted (UTC) Date TOI Updated (UTC)        Date Modified  \
# 0  ...     2018-09-05 18:34:18    2019-12-17 15:43:31  2020-03-04 13:49:16
# 1  ...     2018-09-05 18:34:18    2019-12-17 15:43:39  2020-01-16 02:34:07
# 2  ...     2018-09-05 18:34:18    2019-12-17 15:43:31  2020-01-16 02:34:07
# 3  ...     2018-09-05 18:34:18    2019-12-17 15:43:31  2020-01-16 02:34:07
# 4  ...     2018-09-05 18:34:19    2019-12-17 15:43:31  2020-01-16 02:34:07
#
# ...

# %%
bright = cr.get_below_upper_limit(12, df['TESS Mag'], df['TESS Mag err'])
hi_snr = cr.get_above_lower_limit(1, df['RV_K'], df['RV_K']-df['RV_K_lo'])
# Rp
# Porb
idx = bright & hi_snr
df[idx]
# Out:
#          TIC ID      TOI     Previous CTOI  Master  SG1A  SG1B  SG2  SG3  SG4  \
# 1     149603524   102.01               NaN       5     5     5    5    5    5
# 2     336732616   103.01               NaN       5     5     5    5    5    5
# 3     231670397   104.01               NaN       5     5     5    5    5    5
# 4     144065872   105.01               NaN       5     5     5    5    5    5
# 5      38846515   106.01               NaN       5     5     5    5    5    5
# ...         ...      ...               ...     ...   ...   ...  ...  ...  ...
# 1337   86280613  1786.01               NaN       3     4     3    3    1    4
# 1339  450327768  1788.01               NaN       3     4     3    3    1    4
# 1340  172518755  1789.01               NaN       3     4     3    3    1    4
# 1342  233684293  1791.01               NaN       3     4     3    3    1    4
# 1344  304142124  1793.01  TIC 304142124.01       3     4     3    3    2    4
#
# ...

# %% [markdown]
# ## transits
# * RM/DT
#  * all transiting observable with NRES
#  * Prot+Rs or Vsini from vizier or exofop
#  * At V=10, vsini~120km/s and 0.5 mmag transit, Doppler tomography of this target is well beyond our capabilities with most facilities right now. Our best case scenarios have enabled DTs of 1mmag transits at V<9 for more slowly rotating, line rich stars.
#  * DT candidate: [HJ around a field star](https://exofop.ipac.caltech.edu/tess/target.php?id=371443216)

# %%
bright = cr.get_below_upper_limit(12, df['TESS Mag'], df['TESS Mag err'])

# %% [markdown]
# # By science

# %% [markdown]
# * sub-saturn
# * USP
# * tropical jupiter
